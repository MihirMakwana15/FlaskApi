# %%
import pandas as pd
import random

# Define a list of electronic products
electronics_products = [
    "Laptop", "Smartphone", "Headphones", "Smartwatch", "Tablet",
    "Camera", "Gaming Console", "Desktop Computer", "Portable Charger",
    "Wireless Router", "External Hard Drive", "Bluetooth Speaker",
    "Fitness Tracker", "TV", "Monitor", "Printer", "Keyboard", "Mouse"
]

# Generate example transactions
num_transactions = 150  # Adjust the number of transactions as needed
transactions = []
for i in range(1, num_transactions + 1):
    num_items = random.randint(1, 5)  # Randomly select the number of items in each transaction
    items = random.sample(electronics_products, num_items)  # Randomly select items from the list
    transactions.append({"Transaction ID": i, "Products": ", ".join(items)})

# Create a DataFrame from the transactions
df = pd.DataFrame(transactions)

# Save DataFrame to CSV file
df.to_csv("electronics_transactions.csv", index=False)

# %%
import pandas as pd
import random

# Define clothing products
electronics_products = [
    "Laptop", "Smartphone", "Headphones", "Smartwatch", "Tablet",
    "Camera", "Gaming Console", "Desktop Computer", "Portable Charger",
    "Wireless Router", "External Hard Drive", "Bluetooth Speaker",
    "Fitness Tracker", "TV", "Monitor", "Printer", "Keyboard", "Mouse"
]

# Generate transactions
transactions = []
num_transactions = 150  # Number of transactions

for i in range(num_transactions):
    num_items = random.randint(1, 5)  # Random number of items per transaction
    transaction = random.sample(clothing_products, num_items)
    transactions.append(transaction)

# Create DataFrame with transactions
df = pd.DataFrame(transactions)
df.index.name = 'TransactionID'

# Store DataFrame to CSV file
df.to_csv('clothing_transactions.csv')

# %%
# Apriori

# Run the following command in the terminal toC: pip install apyori

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Data Preprocessing
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
transactions = []
for i in range(0,150):
  transactions.append([str(dataset.values[i,j]) for j in range(0, 4)])

# Training the Apriori model on the dataset
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# Visualising the results

## Displaying the first results coming directly from the output of the apriori function
results = list(rules)
results

## Putting the results well organised into a Pandas DataFrame
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

## Displaying the results non sorted
resultsinDataFrame

## Displaying the results sorted by descending lifts
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#         Left Hand Side      Right Hand Side   Support  Confidence   Lift
# 9            asparagus                salad  0.006667         1.0  150.0
# 88         fresh bread                  oil  0.006667         1.0  150.0
# 89         fresh bread         tomato juice  0.006667         1.0  150.0
# 140                oil         tomato juice  0.006667         1.0  150.0
# 8    antioxydant juice          protein bar  0.006667         1.0   75.0
# 24            brownies           white wine  0.006667         1.0   75.0
# 47             cereals  clothes accessories  0.006667         1.0   75.0
# 69         cooking oil        mashed potato  0.006667         0.5   75.0
# 112               gums                 soda  0.006667         0.5   75.0
# 127        light cream            magazines  0.006667         0.5   75.0

# %%
import pandas as pd

# %%
dataset = pd.read_csv('clothing_transactions.csv')

# %%
dataset.isnull().sum()
# Out:
# TransactionID      0
# 0                  0
# 1                 31
# 2                 57
# 3                 90
# 4                117
# dtype: int64

# %%
dataset.dropna(subset='0',inplace=True)

# %%
dataset.dropna(subset='1',inplace=True)

# %%
dataset.dropna(subset='2',inplace=True)

# %%
dataset.dropna(subset='3',inplace=True)

# %%
dataset.dropna(subset='4',inplace=True)

# %%
dataset
# Out:
#      TransactionID           0           1         2           3           4
# 2                2    Earrings    Necklace    Jacket         Hat    Tank Top
# 3                3       Skirt       Boots   T-shirt      Beanie    Leggings
# 18              18       Scarf    Necklace    Beanie    Bracelet     T-shirt
# 21              21       Scarf  Sweatshirt     Jeans      Beanie       Skirt
# 22              22  Sweatshirt    Sneakers       Hat       Jeans    Leggings
# 27              27       Boots      Jacket       Hat    Earrings      Beanie
# 29              29    Necklace       Heels     Boots       Scarf      Hoodie
# 36              36      Hoodie         Hat    Jacket       Jeans      Clutch
# 38              38         Hat     T-shirt     Skirt    Tank Top       Dress
# 42              42      Beanie      Shorts  Tank Top         Hat       Dress
# 45              45    Bracelet    Earrings  Sneakers    Tank Top      Clutch
# ...

# %%
dataset.isnull().sum()
# Out:
# TransactionID    0
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# dtype: int64
